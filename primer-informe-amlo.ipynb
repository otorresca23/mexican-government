# %% [markdown]
# <h1><center>FIRST GOVERNMENT REPORT</center></h1>
# <h2><center>Andrés Manuel López Obrador</center></h2>

# %% [markdown]
# <h4>Analysis and visualization of text data</h4>
# <h5>The most used informative words during the speech of President Andrés Manuel López Obrador, in his First Government Report.</h5>

# %%
conda config --add channels conda-forge
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import numpy as np
import pandas as pd
from PIL import Image

# %%
#conda search wordcloud --channel conda-forge
#conda install -c conda-forge wordcloud
#conda install -c conda-forge/label/gcc7 wordcloud
#conda install -c conda-forge/label/cf201901 wordcloud
from wordcloud import WordCloud, STOPWORDS

# %%
amlo = open('/Users/cOmrade/Documents/EJERCICIOS_PROPIOS/PRIMER_INFORME_AMLO/amlo.txt', 'r').read()

print ('File downloaded and saved!')
# Out:
# File downloaded and saved!

# %%
stopwords = set(STOPWORDS)

# %%
amlo_wc = WordCloud(
    background_color='white',
    max_words=6927,
    stopwords=stopwords
)

amlo_wc.generate(amlo)

# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('ggplot')

print ('Matplotlib version: ', mpl.__version__)
# Out:
# Matplotlib version:  3.1.0

# %%
plt.imshow(amlo_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
img = Image.open('/Users/cOmrade/Documents/EJERCICIOS_PROPIOS/PRIMER_INFORME_AMLO/IMAGEN/AMLO.png')

# %%
AMLO_MASK = np.array(Image.open('/Users/cOmrade/Documents/EJERCICIOS_PROPIOS/PRIMER_INFORME_AMLO/IMAGEN/AMLO.png'))

# %%
fig = plt.figure()
fig.set_figwidth(42)
fig.set_figheight(54)

plt.imshow(AMLO_MASK, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
stopwords.add('es')
stopwords.add('en')
stopwords.add('para')
stopwords.add('como')
stopwords.add('mil')
stopwords.add('lo')
stopwords.add('del')
stopwords.add('más')
stopwords.add('están')
stopwords.add('de')
stopwords.add('los')
stopwords.add('que')
stopwords.add('se')
stopwords.add('con')
stopwords.add('ni')
stopwords.add('También')
stopwords.add('han')
stopwords.add('un')
stopwords.add('esta')
stopwords.add('este')
stopwords.add('hemos')
stopwords.add('la')
stopwords.add('el')
stopwords.add('pero')
stopwords.add('por ciento')
stopwords.add('nos')
stopwords.add('actual')
stopwords.add('entre')
stopwords.add('año')
stopwords.add('fin')
stopwords.add('desde')
stopwords.add('otro')
stopwords.add('manera')
stopwords.add('ello')
stopwords.add('total')
stopwords.add('ya')
stopwords.add('parte')
stopwords.add('a')
stopwords.add('las')
stopwords.add('por')
stopwords.add('una')
stopwords.add('fue')
stopwords.add('hoy')
stopwords.add('porque')
stopwords.add('será')
stopwords.add('millones dolares')
stopwords.add('toda')
stopwords.add('centro')
stopwords.add('así')
stopwords.add('ha sido')
stopwords.add('son')
stopwords.add('ese')
stopwords.add('sido')
stopwords.add('ha')
stopwords.add('todo')
stopwords.add('al')
stopwords.add('su')
stopwords.add('sin')
stopwords.add('mediante')
stopwords.add('cuando')
stopwords.add('decir')
stopwords.add('cada')
stopwords.add('esa')
stopwords.add('esto')
stopwords.add('asimismo')
stopwords.add('cuanto')
stopwords.add('además')
stopwords.add('nuevo')
stopwords.add('sus')
stopwords.add('ciento')
stopwords.add('está')
stopwords.add('sobre')
stopwords.add('le')
stopwords.add('hasta')
stopwords.add('sí')
stopwords.add('nada')
stopwords.add('julio')
stopwords.add('origen')
stopwords.add('propósito')
stopwords.add('debe')
stopwords.add('donde')
stopwords.add('significa')
stopwords.add('sino')
stopwords.add('nada')
stopwords.add('creado')
stopwords.add('llamada')
stopwords.add('hay')
stopwords.add('pronto')
stopwords.add('relación')
stopwords.add('alta')
stopwords.add('aquí')
stopwords.add('día')
stopwords.add('encima')
stopwords.add('nadie')
stopwords.add('ser')
stopwords.add('material')
stopwords.add('mismo')
stopwords.add('si')
stopwords.add('años')
stopwords.add('pueden')
stopwords.add('mucho')
stopwords.add('meses')
stopwords.add('otros')
stopwords.add('quienes')
stopwords.add('bueno')
stopwords.add('próximo')
stopwords.add('sólo')
stopwords.add('solo')
stopwords.add('centros')
stopwords.add('estamos')
stopwords.add('tienen')
stopwords.add('inició')
stopwords.add('obtuvo')
stopwords.add('resto')
stopwords.add('fuera')
stopwords.add('era')
stopwords.add('nueve')
stopwords.add('diciembre')
stopwords.add('bien')
stopwords.add('General')
stopwords.add('nunca')
stopwords.add('pesos bimestrales')
stopwords.add('pedido')
stopwords.add('les')
stopwords.add('otra')
stopwords.add('haya')
stopwords.add('vamos')
stopwords.add('Ciudad')
stopwords.add('reciben')
stopwords.add('eso')
stopwords.add('creo')
stopwords.add('creó')
stopwords.add('cuatro')
stopwords.add('Viva')
stopwords.add('seis')
stopwords.add('según')
stopwords.add('último')
stopwords.add('palabra')
stopwords.add('llamado')
stopwords.add('nuestra')
stopwords.add('bimestrales')
stopwords.add('directa')
stopwords.add('vez')
stopwords.add('ellos')
stopwords.add('todas')
stopwords.add('toma')
stopwords.add('medio')
stopwords.add('algo')
stopwords.add('forma')
stopwords.add('buenos')
stopwords.add('ahora')
stopwords.add('llamado')
stopwords.add('hecho')
stopwords.add('consiste')
stopwords.add('conseguido')
stopwords.add('vehículo')
stopwords.add('mes')
stopwords.add('consideramos')
stopwords.add('durante')
stopwords.add('primero')
stopwords.add('aplicación')
stopwords.add('cuenta')
stopwords.add('Norte')
stopwords.add('existe')
stopwords.add('antes')
stopwords.add('redujo')
stopwords.add('nivel')
stopwords.add('grupo')
stopwords.add('nueva')
stopwords.add('aumentado')
stopwords.add('aumentó')
stopwords.add('lograr')
stopwords.add('pequeños')
stopwords.add('podido')
stopwords.add('tiene')
stopwords.add('millón')
stopwords.add('mayor')
stopwords.add('nuestro')
stopwords.add('alto')
stopwords.add('importante')
stopwords.add('sana')
stopwords.add('periodo')
stopwords.add('elemento')
stopwords.add('nuestros')
stopwords.add('prioridad')
stopwords.add('mejor')
stopwords.add('objetivo')
stopwords.add('posible')
stopwords.add('informo')
stopwords.add('condiciones')
stopwords.add('pesos mensuales')
stopwords.add('grandes')
stopwords.add('principio')
stopwords.add('materia')
stopwords.add('logré')
stopwords.add('logró')
stopwords.add('criterio')
stopwords.add('primeros')
stopwords.add('fuerza')
stopwords.add('Federal')
stopwords.add('económico')
stopwords.add('ejemplo')
stopwords.add('principal')
stopwords.add('presidencial')
stopwords.add('adicionales')
stopwords.add('legales')
stopwords.add('país')
stopwords.add('México')
stopwords.add('fundamental')
stopwords.add('fenómeno')
stopwords.add('contrario')
stopwords.add('cabo')
stopwords.add('elementos')
stopwords.add('beneficio')
stopwords.add('resolver')
stopwords.add('llevamos')
stopwords.add('Secretaría')
stopwords.add('práctica')
stopwords.add('solución')
stopwords.add('aún')
stopwords.add('daría')
stopwords.add('dará')
stopwords.add('daña')

# %%
AMLO_WC = WordCloud(background_color='white', max_words=6927, mask=AMLO_MASK, stopwords=stopwords)

AMLO_WC.generate(amlo)

fig = plt.figure()
fig.set_figwidth(70)
fig.set_figheight(90)

plt.imshow(AMLO_WC, interpolation='bilinear')
plt.axis('off')
plt.show()
